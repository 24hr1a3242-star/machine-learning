# %%
List=[1,2,3,4,5,6,7,8,9]
print("Original List:\n",List)
print("\nSliced Lists:")
print(List[3:9:2])
print(List[::2])
print(List[::])
print(List[-7:-3])
print(List[::-1])
# Out:
# Original List:
#  [1, 2, 3, 4, 5, 6, 7, 8, 9]
#
# Sliced Lists:
# [4, 6, 8]
# [1, 3, 5, 7, 9]
# [1, 2, 3, 4, 5, 6, 7, 8, 9]
# [3, 4, 5, 6]
# [9, 8, 7, 6, 5, 4, 3, 2, 1]

# %%
List=['Mathematics','Chemistry',1997,2000]
List.append(20544)
print(List)
List.insert(2,10087)
print(List)
List2=[2,3,4,5]
List.extend(List2)
print(List)
print(sum(List2))
List2=[1,2,3,1,2,1,2,3,2,1]
print(List2.count(1))
# Out:
# ['Mathematics', 'Chemistry', 1997, 2000, 20544]
# ['Mathematics', 'Chemistry', 10087, 1997, 2000, 20544]
# ['Mathematics', 'Chemistry', 10087, 1997, 2000, 20544, 2, 3, 4, 5]
# 14
# 4

# %%
test_tup1=('Shiva',"II-I",'MTIET')
test_tup2=('Gowda',"III-I",'MTIET')
print("The original tuple 1:"+str(test_tup1))
print("The original tuple 2:"+str(test_tup2))
res=test_tup1+test_tup2
print("The tuple after concatennation is:"+str(res))
# Out:
# The original tuple 1:('Shiva', 'II-I', 'MTIET')
# The original tuple 2:('Gowda', 'III-I', 'MTIET')
# The tuple after concatennation is:('Shiva', 'II-I', 'MTIET', 'Gowda', 'III-I', 'MTIET')

# %%
def vowel_count(str):
    vowels="aeiouAEIOU"
    count=len([char for char in str if char in vowels])
    print("No.of vowels:",count)
str=input("Enter a String:")
vowel_count(str)
# Out:
# Enter a String:Lohitha
# No.of vowels: 3

# %%
my_dict={1:'a',2:'b',3:'c'}
a=2
if a in my_dict:
    print("Present")
else:
    print("Not Present")
# Out:
# Present

# %%
dict={'College':'MTIET','Course':'B.Tech'}
print("Current Dict is:",dict)
dict['Dept']='CSE-DS'
print("Updated Dict is:",dict)
# Out:
# Current Dict is: {'College': 'MTIET', 'Course': 'B.Tech'}
# Updated Dict is: {'College': 'MTIET', 'Course': 'B.Tech', 'Dept': 'CSE-DS'}

# %%
dic={'x':455,'y':223,'z':300,'p':908}
print("Dictionary:",dic)
print("sum:",sum(dic.values()))
# Out:
# Dictionary: {'x': 455, 'y': 223, 'z': 300, 'p': 908}
# sum: 1886
