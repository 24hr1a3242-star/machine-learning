# %%
a=int(input("enter a number:"))
b=int(input("enter a number:"))
print('The Value of A Before Swapping is:',a)
print('The Value of B Before Swapping is:',b)
a,b=b,a
print('The Value of A After Swapping is:',a)
print('The Value of B After Swapping is:',b)
# Out:
# enter a number:5
# enter a number:6
# The Value of A Before Swapping is: 5
# The Value of B Before Swapping is: 6
# The Value of A After Swapping is: 6
# The Value of B After Swapping is: 5

# %%
a=complex(input("enter a complex number for A:"))
b=complex(input("enter a complex number for B:"))
add=a+b
mul=a*b
print("The sum is:",add)
print("The product is:",mul)
# Out:
# enter a complex number for A:8+4j
# enter a complex number for B:5+3j
# The sum is: (13+7j)
# The product is: (28+44j)

# %%
num=int(input("enter an integer:"))
for i in range(1,11):
    res=num*i
    print('{0} X {1} ={2} '.format(num,i,res))
# Out:
# enter an integer:6
# 6 X 1 =6
# 6 X 2 =12
# 6 X 3 =18
# 6 X 4 =24
# 6 X 5 =30
# 6 X 6 =36
# 6 X 7 =42
# 6 X 8 =48
# 6 X 9 =54
# 6 X 10 =60

# %%
a=int(input("enter a number for A:"))
b=int(input("enter a number for B:"))
add=a+b
sub=a-b
mul=a*b
div=a/b
mod=a%b
print("The sum is:",add)
print("The difference is:",sub)
print("The product is:",mul)
print("The division is:",div)
print("The modulus is:",mod)
# Out:
# enter a number for A:6
# enter a number for B:4
# The sum is: 10
# The difference is: 2
# The product is: 24
# The division is: 1.5
# The modulus is: 2
