# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
a=5,6
print(type(a))
# Out:
# <class 'tuple'>

# %%
a=5+3j
print(type(a))
# Out:
# <class 'complex'>

# %%
a=True
print(type(a))
# Out:
# <class 'bool'>

# %%
a=False
print(type(a))
# Out:
# <class 'bool'>

# %%
s='MTIET'
print(type(s))
# Out:
# <class 'str'>

# %%
s="MTIET"
print(type(s))
# Out:
# <class 'str'>

# %%
s="'MTIET'"
print(type(s))
# Out:
# <class 'str'>

# %%
S='MTIET PALAMANER'
print(S[4])
# Out:
# T

# %%
s='MTIET PALAMANER'
print(s[:])
# Out:
# MTIET PALAMANER

# %%
s='MTIET PALAMANER'
print(s[:7])
# Out:
# MTIET P

# %%
s='MTIET PALAMANER'
print(s[-15:])
# Out:
# MTIET PALAMANER

# %%
s1='MTIET'
s2='PALAMANER'
print(s1*3)
# Out:
# MTIETMTIETMTIET

# %%
I=[2,3,5,7,'hello',[1,2,3,4]]
print(I[4:])
# Out:
# ['hello', [1, 2, 3, 4]]

# %%
t1=[2,4,5.6,'hello',[1,2,3]]
print(type(t1))
# Out:
# <class 'list'>

# %%
t1=5,6,7
print(type(t1))
# Out:
# <class 'tuple'>

# %%
a,b,c=5,6,7
print(a)
# Out:
# 5

# %%
a=input('enter value of a:')
print(type(a))

# %%
a=input('enter value of a:')
print(type(a))
# Out:
# enter value of a:3+5j
# <class 'str'>

# %%
a=input('enter value of a:')
print(type(a))
# Out:
# enter value of a:5
# <class 'str'>

# %%
a=int(input('enter value of a:'))
b=int(input('enter value of b:'))
c=int(input('enter value of c:'))
if a>b and a>c:
    print("A is larger")
elif b>a and b>c:
    print("B is larger")
else:
    print("C is larger")
# Out:
# enter value of a:5
# enter value of b:3
# enter value of c:7
# C is larger

# %%
x=int(input("enter starting value:"))
y=int(input("enter ending value:"))
for num in range(x,y+1):
    if num>1:
        for i in range(2,num):
            if num%i==0:
                break
            else:
                    print(num)
# Out:
# enter starting value:2
# enter ending value:10
# 3
# 5
# 5
# 5
# 7
# 7
# 7
# 7
# 7
# 9
